# %%
def my_function():
    # This is a sample function
    return "Hello, World!"

my_function()
# Out:
# 'Hello, World!'

# %%
def factorial(n):
    if n == 0:
        return 1
    else:
        return n * factorial(n-1)
    
print(factorial(5))
# Out:
# 120
