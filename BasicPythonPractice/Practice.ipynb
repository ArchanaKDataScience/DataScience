# %%
print("Hello World!"[::-1][-5:])
# Out:
# olleH

# %%
print("Hello World!"[::-1])
# Out:
# !dlroW olleH

# %%
print("Hello World!"[::-1][-5:][-1])
# Out:
# H

# %%
print(0.1 + 0.2==0.3)
# Out:
# False

# %%
s="Coding"
print(s[10:0:-1])
# Out:
# gnido

# %%
s="Coding"
print(s[:10])
# Out:
# Coding

# %%
print("2" + "3"*2)
# Out:
# 233

# %%
x="A"
y=5
print(len(x)*y )
# Out:
# 5

# %%
x="12"
if x>"2":
    print("Greater")
else:
    print("Smaller")
# Out:
# Smaller

# %%
#**Question:** Write a program that accepts a sentence and prints the longest word. 
text = input("Enter a sentence: ")
words = text.split() 
longest_word = max(words, key=len) 
print("Longest word:", longest_word)
# Out:
# Longest word: Acbbmndskhdk
