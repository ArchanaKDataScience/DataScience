# %%
import numpy as np

# %%
 a = np.arange(6)
 a2 = a[np.newaxis, :]
 a2.shape
# Out:
# (1, 6)

# %%
for i in range(3):
  x=i
x
# Out:
# 2

# %%
np.arange(2, 9, 2)
# Out:
# array([2, 4, 6, 8])

# %%
'''
 you can also use 
np.linspace()
 to create an array with values that are spaced linearly in a speci ed
interval:
'''
np.linspace(0, 10, num=5)
# Out:
# array([ 0. ,  2.5,  5. ,  7.5, 10. ])

# %%
arr = np.array([2, 1, 5, 3, 7, 4, 6, 8])
arr.sort()
print(arr)
# Out:
# [1 2 3 4 5 6 7 8]

# %%
a = np.array([1, 2, 3, 4])
b = np.array([5, 6, 7, 8])
np.concatenate((a, b))
# Out:
# array([1, 2, 3, 4, 5, 6, 7, 8])

# %%
x = np.array([[1, 2], [3, 4]])
y = np.array([[5, 6]])
np.concatenate((x, y), axis=0)
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
'''argsort, which is an indirect sort along a speci ed axis,
lexsort, which is an indirect stable sort on multiple keys,
searchsorted, which will nd elements in a sorted array, and
partition, which is a partial sort.'''
