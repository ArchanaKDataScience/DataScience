# %%
import colorsys
from turtle import *

tracer(10)
bgcolor("black")
h=0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 import colorsys
# ----> 3 tracer(10)
#       4 bgcolor("black")
#       5 h=0
#
# NameError: name 'tracer' is not defined
